# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

google = [["01/01/2019","01/01/2020","01/01/2021","01/01/2022","01/01/2023"],[9.7,8.6,10.8,12.6,14.3]]

csv_file = "E:/multiTimeline.csv"
csv_clean = pd.read_csv(csv_file, skiprows=3, low_memory=False)

power = pd.DataFrame([[120, 108, 96, 84, 72, 60, 48], [1567.512488, 1412.272194, 1271.674422, 1126.373758, 992.6899945, 861.8969161, 360.0429636]]).transpose()
plt.plot(power[0],power[1],'o')
